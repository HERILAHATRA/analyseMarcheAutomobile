# %%
import sys
import os
# 1. On pointe vers le dossier des recettes (src)
sys.path.append(os.path.abspath('../src'))

# 2. On importe l'outil que tu as déjà fabriqué
from kpi_calculation import calculer_kpis_vente

# 3. On récupère les résultats directement
# (La fonction fait tout le travail de group_by et de moyenne en coulisses)
stats, top_marques = calculer_kpis_vente('../data/cleaned/car_prices_enriched.parquet')

# 4. On affiche juste le résultat final
print("Voici le signal extrait des données :")
print(top_marques)
# Out:
# Voici le signal extrait des données :
# shape: (10, 3)
# ┌───────────┬───────────────┬──────────────┐
# │ make      ┆ nombre_ventes ┆ prix_moyen   │
# │ ---       ┆ ---           ┆ ---          │
# │ str       ┆ u32           ┆ f64          │
# ╞═══════════╪═══════════════╪══════════════╡
# │ Ford      ┆ 81013         ┆ 14829.809413 │
# │ Chevrolet ┆ 54150         ┆ 11866.210434 │
# │ Nissan    ┆ 44043         ┆ 11745.442885 │
# │ Toyota    ┆ 35313         ┆ 12422.457197 │
# │ Dodge     ┆ 27181         ┆ 10963.794342 │
# │ Honda     ┆ 24781         ┆ 10942.928453 │
# │ Hyundai   ┆ 18659         ┆ 11062.017418 │
# │ BMW       ┆ 17509         ┆ 21290.043863 │
# │ Kia       ┆ 15828         ┆ 11767.570824 │
# │ Chrysler  ┆ 15133         ┆ 10627.087887 │
# └───────────┴───────────────┴──────────────┘
